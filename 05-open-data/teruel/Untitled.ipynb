# %% [markdown]
# # Teruel

# %%
import urllib.request, json
import requests
import pandas as pd

# %% [markdown]
# # GetCount
#
# Análizamos el resultado de uno de los endpoints disponibles y vemos que existe un total de 100 datasets en Teruel.

# %%
get_count_uri = "https://236ws.dpteruel.es/transparencia/dpteruel/open-data/api/v1/getCount"
r = requests.get(get_count_uri)
total_dataset_count = r.json()['result']['results']
print(total_dataset_count)
# Out:
# [100]

# %% [markdown]
# # GetAll
#
# Hacemos una primera petición para obtener todos los datasets y ver con que podemos trabajar y descubrimos que de los 100 indicados en el apartado anterior tan solo vemos 8 resultados disponibles.

# %%
get_all_uri = "https://236ws.dpteruel.es/transparencia/dpteruel/open-data/api/v1/getAll"
r = requests.get(get_all_uri)
all_datasets = r.json()['result']['results']
all_datasets_df = pd.DataFrame.from_dict(all_datasets)
all_datasets_df = all_datasets_df.set_index('id')
all_datasets_df.shape
# Out:
# (10, 7)

# %% [markdown]
# Como podemos ver tenemos los siguientes campos disponibles:

# %%
all_datasets_df.columns.values
# Out:
# array(['title', 'url', 'date', 'last_modified_date', 'categories',
#        'resources', 'tags'], dtype=object)

# %%
all_datasets_df.head()
# Out:
#                                                   title  \
# id
# 2751  Informes periódicos de la ejecución de los pre...
# 2744  Liquidación del presupuesto del ejercicio ante...
# 2741              Presupuestos generales anuales - 2021
# 2641  Informes periódicos de la ejecución de los pre...
# 2599  Cumplimiento de los periodos de pago a proveed...
#
#                                                     url                 date  \
# id
# 2751  https://236ws.dpteruel.es/transparencia/dpteru...  2021-05-05 10:39:02
# 2744  https://236ws.dpteruel.es/transparencia/dpteru...  2021-05-05 10:29:34
# 2741  https://236ws.dpteruel.es/transparencia/dpteru...  2021-03-01 11:58:59
# 2641  https://236ws.dpteruel.es/transparencia/dpteru...  2020-05-26 10:47:02
# 2599  https://236ws.dpteruel.es/transparencia/dpteru...  2020-02-10 11:33:40
#
#        last_modified_date  categories  \
# id
# 2751  2021-05-05 10:39:47  [Economía]
# 2744  2021-05-05 10:30:58  [Economía]
# 2741  2021-03-01 12:01:30  [Economía]
# 2641  2021-02-23 11:47:31  [Economía]
# 2599  2021-01-25 11:34:32  [Economía]
#
#                                               resources tags
# id
# 2751  [{'url': 'https://236ws.dpteruel.es/transparen...  NaN
# 2744  [{'url': 'https://236ws.dpteruel.es/transparen...  NaN
# 2741  [{'url': 'https://236ws.dpteruel.es/transparen...  NaN
# 2641  [{'url': 'https://236ws.dpteruel.es/transparen...  NaN
# 2599  [{'url': 'Periodo Medio de Pago enero 2020', '...  NaN

# %% [markdown]
# Si nos fijamos solamente en los titulos de los datasets, vemos que todos ellos hacen referencia a presupuestos.

# %%
all_datasets_df.title.to_list()
# Out:
# ['Informes periódicos de la ejecución de los presupuestos - Ejercicio 2021',
#  'Liquidación del presupuesto del ejercicio anterior (2020)',
#  'Presupuestos generales anuales - 2021',
#  'Informes periódicos de la ejecución de los presupuestos - Ejercicio 2020',
#  'Cumplimiento de los periodos de pago a proveedores - Ejercicio 2020',
#  'Modificaciones presupuestarias aprobadas - Ejercicio 2020',
#  'Inversión financieramente sostenible 2020 a financiar con el superávit presupuestario de la Liquidación del Presupuesto de 2019',
#  'Liquidación del presupuesto del ejercicio anterior (2019)',
#  'Plan presupuestario a medio plazo (2021-2023) de la Diputación Provincial de Teruel',
#  'Plan estratégico de subvenciones 2020-2023']

# %%
all_datasets_df.categories
# Out:
# id
# 2751            [Economía]
# 2744            [Economía]
# 2741            [Economía]
# 2641            [Economía]
# 2599            [Economía]
# 2613            [Economía]
# 2690            [Economía]
# 2647            [Economía]
# 2638            [Economía]
# 2607    [Plan estratégico]
# Name: categories, dtype: object

# %%
all_datasets_df.tags
# Out:
# id
# 2751                                 NaN
# 2744                                 NaN
# 2741                                 NaN
# 2641                                 NaN
# 2599                                 NaN
# 2613                                 NaN
# 2690                                 NaN
# 2647                                 NaN
# 2638                                 NaN
# 2607    [plan estratégico, subvenciones]
# Name: tags, dtype: object

# %% [markdown]
# # Recursos disponibles
#
# Si creamos un dataset con los recursos de todos los conjuntos de datos disponibles vemosque tenemos un total de 54 a nuestra dispocición. Algo que dista mucho de los 100 que nos habían indicado al inicio.

# %%
columns = ['title', 'categories', 'tags', 'resources']
all_datasets_df = all_datasets_df[columns]
all_datasets_df['tags'] = all_datasets_df['tags'].apply(lambda d: d if isinstance(d, list) else [])
all_datasets_df.resources.to_list()[0]
# Out:
# [{'url': 'https://236ws.dpteruel.es/transparencia/dpteruel/recurso/economia/ejec-presu/P4400000H-2021-LIQUIDACION-TRIMESTRAL-PRESUPUESTOS-1T.xml',
#   'description': 'Informe de ejecución del presupuesto de la Diputación, 1er. trimestre 2021',
#   'title': 'Informe de ejecución del presupuesto de la Diputación, 1er. trimestre 2021',
#   'format': 'XML'},
#  {'url': 'https://236ws.dpteruel.es/transparencia/dpteruel/recurso/economia/ejec-presu/G44010965-2021-LIQUIDACION-TRIMESTRAL-PRESUPUESTOS-1T.xml',
#   'description': 'Informe de ejecución del presupuesto del Instituto de Estudios Turolenses, 1er. trimestre 2021',
#   'title': 'Informe de ejecución del presupuesto del Instituto de Estudios Turolenses, 1er. trimestre 2021',
#   'format': 'XML'}]

# %%
resources = all_datasets_df.resources.to_list()
resources_df = pd.DataFrame(columns=['url', 'description', 'title', 'format'])
for dataset_resources in resources:
    resources_df = resources_df.append(dataset_resources, ignore_index=True)

resources_df.shape
# Out:
# (54, 4)

# %% [markdown]
# Si vemos los formatos disponibles, veremos que tan solo hay tres posibilidades y uno desconocido.

# %%
resources_df.format.unique()
# Out:
# array(['XML', 'TXT', None, 'PDF'], dtype=object)

# %% [markdown]
# # TXT
#
# Si miramos los recursos en formato TXT vemos que los resultados son comprensibles y puede que transladables a un dataFrame, parece una salidad de una consulta de SQL.

# %%
resources_df[resources_df.format == 'TXT'].url.to_list()
# Out:
# ['https://236ws.dpteruel.es/transparencia/dpteruel/recurso/economia/ejec-presu/MINHAP-PRIMER-TRIMESTRE-DPT-2020-1T.txt',
#  'https://236ws.dpteruel.es/transparencia/dpteruel/recurso/economia/ejec-presu/MINHAP-SEGUNDO-TRIMESTRE-DPT-2020-2T.txt',
#  'https://236ws.dpteruel.es/transparencia/dpteruel/recurso/economia/ejec-presu/MINHAP-SEGUNDO-TRIMESTRE-DPT-2020-3T.txt']

# %% [markdown]
# # XML

# %%
resources_df[resources_df.format == 'XML'].url.to_list()

# %% [markdown]
# # PDF

# %%
resources_df[resources_df.format == 'PDF'].url.to_list()
# Out:
# ['https://236ws.dpteruel.es/transparencia/dpteruel/recurso/economia/modif-ppto/EXPTE-MODIF-CTO-01-2020-DPT.pdf',
#  'https://236ws.dpteruel.es/transparencia/dpteruel/recurso/economia/modif-ppto/EXPTE-MODIF-CTO-02-2020-DPT.pdf',
#  'https://236ws.dpteruel.es/transparencia/dpteruel/recurso/economia/modif-ppto/EXPTE-MODIF-CTO-03-2020-DPT.pdf',
#  'https://236ws.dpteruel.es/transparencia/dpteruel/recurso/economia/modif-ppto/EXPTE-MODIF-CTO-04-2020-DPT.pdf',
#  'https://236ws.dpteruel.es/transparencia/dpteruel/recurso/economia/modif-ppto/EXPTE-MODIF-CTO-05-2020-DPT.pdf',
#  'https://236ws.dpteruel.es/transparencia/dpteruel/recurso/economia/modif-ppto/EXPTE-MODIF-CTO-06-2020-DPT.pdf',
#  'https://236ws.dpteruel.es/transparencia/dpteruel/recurso/economia/modif-ppto/EXPTE-MODIF-CTO-07-2020-DPT.pdf',
#  'https://236ws.dpteruel.es/transparencia/dpteruel/recurso/economia/modif-ppto/EXPTE-MODIF-CTO-08-2020-DPT.pdf',
#  'https://236ws.dpteruel.es/transparencia/dpteruel/recurso/economia/modif-ppto/EXPTE-MODIF-CTO-09-2020-DPT.pdf',
#  'https://236ws.dpteruel.es/transparencia/dpteruel/recurso/economia/modif-ppto/EXPTE-MODIF-CTO-10-2020-DPT.pdf',
#  'https://236ws.dpteruel.es/transparencia/dpteruel/recurso/economia/modif-ppto/EXPTE-MODIF-CTO-11-2020-DPT.pdf',
#  'https://236ws.dpteruel.es/transparencia/dpteruel/recurso/economia/modif-ppto/EXPTE-MODIF-CTO-12-2020-DPT.pdf',
#  'https://236ws.dpteruel.es/transparencia/dpteruel/recurso/economia/modif-ppto/EXPTE-MODIF-CTO-13-2020-DPT.pdf',
#  'https://236ws.dpteruel.es/transparencia/dpteruel/recurso/economia/modif-ppto/EXPTE-MODIF-CTO-14-2020-DPT.pdf',
#  'https://236ws.dpteruel.es/transparencia/dpteruel/recurso/economia/INF-INV-FIN-SOST-SUPERAVIT.pdf',
#  'https://236ws.dpteruel.es/transparencia/dpteruel/recurso/economia/liq-ptto-anterior-2019/P4400000H-2019-LIQUIDACION-PRESUPUESTOS.pdf',
#  'https://236ws.dpteruel.es/transparencia/dpteruel/recurso/economia/liq-ptto-anterior-2019/G44010965-2019-LIQUIDACION-PRESUPUESTOS.pdf',
#  'https://236ws.dpteruel.es/transparencia/dpteruel/recurso/economia/PLAN-PRESUPUESTARIO-DPT-2021-2023.pdf',
#  'https://236ws.dpteruel.es/transparencia/dpteruel/recurso/legislacion-justicia/PES 2020-2023TextoConsolidado.pdf']

# %% [markdown]
# # Analisis primer trimestre 2021
#
# https://236ws.dpteruel.es/transparencia/dpteruel/recurso/economia/ejec-presu/P4400000H-2021-LIQUIDACION-TRIMESTRAL-PRESUPUESTOS-1T.xml

# %%
liquidacion_trimestral_uri = 'https://236ws.dpteruel.es/transparencia/dpteruel/wp-content/uploads/sites/3/2021/05/P4400000H-2021-LIQUIDACION-TRIMESTRAL-PRESUPUESTOS-1T.xml'

import xml.etree.ElementTree as ET
r = requests.get(liquidacion_trimestral_uri)
tree = ET.ElementTree(ET.fromstring(r.text))
root = tree.getroot()

liquidacion_trimestral_df = pd.DataFrame(columns=['decimals', 'contextRef', 'unitRef'])
amount = []
for child in root:
    if 'unitRef' in child.attrib: 
#         print("attrib: {}\nelement.text: {}\n".format(child.attrib, child.text))
        liquidacion_trimestral_df = liquidacion_trimestral_df.append(child.attrib, ignore_index=True)
        amount.append(child.text)

liquidacion_trimestral_df['amount'] = amount
liquidacion_trimestral_df = liquidacion_trimestral_df.rename(columns={'contextRef': 'reference', 'unitRef': 'currency'})

liquidacion_trimestral_df.shape
# Out:
# (1629, 4)

# %%
liquidacion_trimestral_df.head()
# Out:
#   decimals                                          reference currency  \
# 0        2  IdContextosEconomicaIngresos_ImpuestosSobreLaR...     euro
# 1        2  IdContextosEconomicaIngresos_ImpuestosSobreLaR...     euro
# 2        2  IdContextosEconomicaIngresos_ImpuestosSobreLaR...     euro
# 3        2  IdContextosEconomicaIngresos_ImpuestosSobreLaR...     euro
# 4        2  IdContextosEconomicaIngresos_ImpuestosSobreLaR...     euro
#
#        amount
# 0  1316220.00
# 1   329055.30
# 2   329055.30
# 3        0.00
# 4  1316220.00

# %%
liquidacion_trimestral_df.describe()
# Out:
#        decimals                                          reference currency  \
# count      1629                                               1629     1629
# unique        2                                                294        1
# top           2  IdContextosEconomicaIngresos_ImpuestosSobreLaR...     euro
# freq       1581                                                  6     1629
#
#        amount
# count    1372
# unique    480
# top      0.00
# freq      416

# %%
liquidacion_trimestral_df.isnull().sum()
# Out:
# decimals       0
# reference      0
# currency       0
# amount       257
# dtype: int64

# %%
liquidacion_trimestral_df.reference.unique()[:9]
# Out:
# array(['IdContextosEconomicaIngresos_ImpuestosSobreLaRentaDeLasPersonasFisicas',
#        'IdContextosEconomicaIngresos_ImpuestoSobreLaRenta',
#        'IdContextosEconomicaIngresos_RecargoProvincialEnElImpuestoSobreActividadesEconomicas',
#        'IdContextosEconomicaIngresos_RecargosSobreImpuestosDirectosDeOtrosEntesLocales',
#        'IdContextosEconomicaIngresos_ImpuestosDirectos',
#        'IdContextosEconomicaIngresos_ImpuestoSobreElValorAnadido',
#        'IdContextosEconomicaIngresos_ImpuestosSobreElValorAnadido',
#        'IdContextosEconomicaIngresos_ImpuestoSobreElAlcoholYBebidasDerivadas',
#        'IdContextosEconomicaIngresos_ImpuestoSobreLaCerveza'],
#       dtype=object)

# %%
liquidacion_trimestral_df.decimals.unique()
# Out:
# array(['2', '0'], dtype=object)

# %%
liquidacion_trimestral_df.currency.unique()
# Out:
# array(['euro'], dtype=object)

# %%
liquidacion_trimestral_df.amount = liquidacion_trimestral_df.amount.fillna(0)

# %%
liquidacion_trimestral_df.describe()
# Out:
#        decimals                                          reference currency  \
# count      1629                                               1629     1629
# unique        2                                                294        1
# top           2  IdContextosEconomicaIngresos_ImpuestosSobreLaR...     euro
# freq       1581                                                  6     1629
#
#        amount
# count    1629
# unique    481
# top      0.00
# freq      416

# %%
liquidacion_trimestral_uri = 'https://236ws.dpteruel.es/transparencia/dpteruel/wp-content/uploads/sites/3/2021/05/P4400000H-2021-LIQUIDACION-TRIMESTRAL-PRESUPUESTOS-1T.xml'
from lxml import etree
from io import StringIO 
import xml.etree.ElementTree as ET

r = requests.get(liquidacion_trimestral_uri)
tree = ET.ElementTree(ET.fromstring(r.text))

print(r.encoding)

# foo = bytes(r.content, encoding='utf8')
tree2 = etree.parse(r.content.decode('utf-8'))

root = tree.getroot()

entidades = pd.DataFrame(columns=['id', 'entity', 'period'])
for child in root.findall('{http://www.xbrl.org/2003/instance}context'):
    identifier = child.get('id')
    entidad = child[0][0].text
    entidad = child[0][1][0].text
    periodo = child[1][0].text
    entidades = entidades.append({'id': identifier, 'entity': entidad, 'period': periodo}, ignore_index=True)
    
entidades.shape
# Out:
# UTF-8
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_421/3700074516.py in <module>
#      10
#      11 # foo = bytes(r.content, encoding='utf8')
# ---> 12 tree2 = etree.parse(r.content.decode('utf-8'))
#      13
#      14 root = tree.getroot()
#
# src/lxml/etree.pyx in lxml.etree.parse()
#
# src/lxml/parser.pxi in lxml.etree._parseDocument()
#
# src/lxml/parser.pxi in lxml.etree._parseDocumentFromURL()
#
# src/lxml/parser.pxi in lxml.etree._parseDocFromFile()
#
# src/lxml/parser.pxi in lxml.etree._BaseParser._parseDocFromFile()
#
# src/lxml/parser.pxi in lxml.etree._ParserContext._handleParseResultDoc()
#
# src/lxml/parser.pxi in lxml.etree._handleParseResult()
#
# src/lxml/parser.pxi in lxml.etree._raiseParseError()
#
# OSError: Error reading file '<?xml version="1.0" encoding="UTF-8"?>
# <!-- Generated by GESTION 400 on IBM iSeries -->
# <xbrli:xbrl xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://xbrl.org/2006/xbrldi http://www.xbrl.org/2006/xbrldi-2006.xsd" xmlns:trimloc2017="http://www.meh.es/taxonomias/trimloc2017" xmlns:trimloc2017-econ-ingr="http://www.meh.es/taxonomias/trimloc2017-econ-ingr" xmlns:trimloc2017-resultp="http://www.meh.es/taxonomias/trimloc2017-resultp" xmlns:trimloc2017-exist="http://www.meh.es/taxonomias/trimloc2017-exist" xmlns:xbrldt="http://xbrl.org/2005/xbrldt"
#  xmlns:trimloc2017-ref="http://www.meh.es/taxonomias/trimloc2017-ref" xmlns:trimloc2017-econ-gast-cuentas="http://www.meh.es/taxonomias/trimloc2017-econ-gast-cuentas"                                                                                                                                                       xmlns:trimloc2017-prog-cuentas-econ-cruzadas="http://www.meh.es/taxonomias/trimloc2017-prog-cuentas-econ-cruzadas" xmlns:link="http://www.xbrl.org/2003/linkbase"
#  xmlns:trimloc2017-econ-ingr-cuentas="http://www.meh.es/taxonomias/trimloc2017-econ-ingr-cuentas" xmlns:trimloc2017-econ-gast="http://www.meh.es/taxonomias/trimloc2017-econ-gast"                                                                                          xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:trimloc2017-prog="http://www.meh.es/taxonomias/trimloc2017-prog"                                                                       xmlns:iso4217="http://www.xbrl.org/2003/iso4217"
#  xmlns:trimloc2017-prog-cuentas="http://www.meh.es/taxonomias/trimloc2017-prog-cuentas"                                              xmlns:trimloc2017-anexo5="http://www.meh.es/taxonomias/trimloc2017-anexo5"  xmlns:trimloc2017-remt="http://www.meh.es/taxonomias/trimloc2017-remt" xmlns:trimloc2017-anexo4="http://www.meh.es/taxonomias/trimloc2017-anexo4" xmlns:trimloc2017-anexo3="http://www.meh.es/taxonomias/trimloc2017-anexo3"   xmlns:xbrldi="http://xbrl.org/2006/xbrldi"
#  xmlns:trimloc2017-anexo2="http://www.meh.es/taxonomias/trimloc2017-anexo2"                                                                                xmlns:trimloc2017-econ-ingr-importes="http://www.meh.es/taxonomias/trimloc2017-econ-ingr-importes" xmlns:trimloc2017-econ-gast-importes="http://www.meh.es/taxonomias/trimloc2017-econ-gast-importes" xmlns:trimloc2017-anexo1="http://www.meh.es/taxonomias/trimloc2017-anexo1" xmlns:xbrli="http://www.xbrl.org/2003/instance">
#   <link:schemaRef xlink:type="simple" xlink:href="../lenloc2010/trimloc2017.xsd"/>
#   <xbrli:context id="IdContextoDatosBasicos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_EconomicaIngresos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:EconomicaIngresos</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_ImpuestosDirectos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:ImpuestosDirectos</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_ImpuestosIndirectos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:ImpuestosIndirectos</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TasasPreciosPublicosYOtrosIngresos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:TasasPreciosPublicosYOtrosIngresos</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TasasPorLaPrestacionDeServiciosPublicosDeCaracterSocialYPreferente">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:TasasPorLaPrestacionDeServiciosPublicosDeCaracterSocialYPreferente</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TasasPorLaRealizacionDeActividadesDeCompetenciaLocal">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:TasasPorLaRealizacionDeActividadesDeCompetenciaLocal</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TasasPorLaUtilizacionPrivativaOElAprovechamientoEspecialDelDominioPublicoLocal">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:TasasPorLaUtilizacionPrivativaOElAprovechamientoEspecialDelDominioPublicoLocal</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_PreciosPublicos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:PreciosPublicos</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_ContribucionesEspeciales">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:ContribucionesEspeciales</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_Ventas">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:Ventas</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_ReintegrosDeOperacionesCorrientes">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:ReintegrosDeOperacionesCorrientes</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_OtrosIngresos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:OtrosIngresos</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TransferenciasCorrientes">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:TransferenciasCorrientes</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_IngresosPatrimoniales">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:IngresosPatrimoniales</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_EnajenacionDeInversionesReales">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:EnajenacionDeInversionesReales</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_EconomicaIngresos_TransferenciasDeCapital">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:EconomicaIngresos_TransferenciasDeCapital</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_EconomicaIngresos_ActivosFinancieros">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:EconomicaIngresos_ActivosFinancieros</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_EconomicaIngresos_PasivosFinancieros">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:EconomicaIngresos_PasivosFinancieros</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_ImpuestoSobreLaRenta">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:ImpuestoSobreLaRenta</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_ImpuestosSobreElCapital">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:ImpuestosSobreElCapital</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_ImpuestoSobreLasActividadesEconomicas">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:ImpuestoSobreLasActividadesEconomicas</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_RecargosSobreImpuestosDirectosDelEstadoYDeLaComunidadAutonoma">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:RecargosSobreImpuestosDirectosDelEstadoYDeLaComunidadAutonoma</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_RecargosSobreImpuestosDirectosDeOtrosEntesLocales">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:RecargosSobreImpuestosDirectosDeOtrosEntesLocales</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_ImpuestosDirectosExtinguidos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:ImpuestosDirectosExtinguidos</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_OtrosImpuestosDirectos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:OtrosImpuestosDirectos</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_ImpuestosSobreElValorAnadido">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:ImpuestosSobreElValorAnadido</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_SobreConsumosEspecificos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:SobreConsumosEspecificos</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_RecargosSobreImpuestosIndirectosDelEstadoYDeLaComunidadAutonoma">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:RecargosSobreImpuestosIndirectosDelEstadoYDeLaComunidadAutonoma</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_RecargosSobreImpuestosIndirectosDeOtrosEntesLocales">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:RecargosSobreImpuestosIndirectosDeOtrosEntesLocales</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_ImpuestosIndirectosExtinguidos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:ImpuestosIndirectosExtinguidos</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_OtrosImpuestosIndirectos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:OtrosImpuestosIndirectos</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TasasPorLaPrestacionDeServiciosPublicosBasicos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:TasasPorLaPrestacionDeServiciosPublicosBasicos</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TasasPorLaPrestacionDeServiciosPublicosDeCaracterSocialYPreferente_ServiciosHospitalarios">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:TasasPorLaPrestacionDeServiciosPublicosDeCaracterSocialYPreferente_ServiciosHospitalarios</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TasasPorLaPrestacionDeServiciosPublicosDeCaracterSocialYPreferente_ServiciosAsistenciales">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:TasasPorLaPrestacionDeServiciosPublicosDeCaracterSocialYPreferente_ServiciosAsistenciales</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TasasPorLaPrestacionDeServiciosPublicosDeCaracterSocialYPreferente_ServiciosEducativos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:TasasPorLaPrestacionDeServiciosPublicosDeCaracterSocialYPreferente_ServiciosEducativos</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TasasPorLaPrestacionDeServiciosPublicosDeCaracterSocialYPreferente_ServiciosDeportivos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:TasasPorLaPrestacionDeServiciosPublicosDeCaracterSocialYPreferente_ServiciosDeportivos</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_OtrasTasasPorPrestacionDeServiciosDeCaracterPreferente">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:OtrasTasasPorPrestacionDeServiciosDeCaracterPreferente</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_LicenciasDeCazaYPesca">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:LicenciasDeCazaYPesca</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_LicenciasUrbanisticas">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:LicenciasUrbanisticas</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_CedulasDeHabitabilidadYLicenciasDePrimeraOcupacion">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:CedulasDeHabitabilidadYLicenciasDePrimeraOcupacion</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TasasPorOtrosServiciosUrbanisticos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:TasasPorOtrosServiciosUrbanisticos</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TasasSobreElJuego">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:TasasSobreElJuego</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TasaPorExpedicionDeDocumentos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:TasaPorExpedicionDeDocumentos</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TasaPorRetiradaDeVehiculos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:TasaPorRetiradaDeVehiculos</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_OtrasTasasPorLaRealizacionDeActividadesDeCompetenciaLocal">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:OtrasTasasPorLaRealizacionDeActividadesDeCompetenciaLocal</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TasaDeEstacionamientoDeVehiculos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:TasaDeEstacionamientoDeVehiculos</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TasaPorEntradaDeVehiculos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:TasaPorEntradaDeVehiculos</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TasaPorUtilizacionPrivativaOAprovechamientoEspecialPorEmpresasExplotadorasDeServiciosDeSuministros">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:TasaPorUtilizacionPrivativaOAprovechamientoEspecialPorEmpresasExplotadorasDeServiciosDeSuministros</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TasaPorUtilizacionPrivativaOAprovechamientoEspecialPorEmpresasExplotadorasDeServiciosDeTelecomunicaciones">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:TasaPorUtilizacionPrivativaOAprovechamientoEspecialPorEmpresasExplotadorasDeServiciosDeTelecomunicaciones</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TasaPorAperturaDeCalasYZanjas">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:TasaPorAperturaDeCalasYZanjas</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TasaPorOcupacionDeLaViaPublicaConTerrazas">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:TasaPorOcupacionDeLaViaPublicaConTerrazas</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TasaPorOcupacionDeLaViaPublicaConSuspensionTemporalDelTraficoRodado">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:TasaPorOcupacionDeLaViaPublicaConSuspensionTemporalDelTraficoRodado</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TasasPorAprovechamientoDelVuelo">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:TasasPorAprovechamientoDelVuelo</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_CompensacionDeTelefonicaDeEspanaSa">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:CompensacionDeTelefonicaDeEspanaSa</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_OtrasTasasPorUtilizacionPrivativaDelDominioPublico">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:OtrasTasasPorUtilizacionPrivativaDelDominioPublico</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_PreciosPublicos_ServiciosHospitalarios">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:PreciosPublicos_ServiciosHospitalarios</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_PreciosPublicos_ServiciosAsistenciales">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:PreciosPublicos_ServiciosAsistenciales</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_PreciosPublicos_ServiciosEducativos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:PreciosPublicos_ServiciosEducativos</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_PreciosPublicos_ServiciosDeportivos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:PreciosPublicos_ServiciosDeportivos</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_EntradasAMuseosExposicionesEspectaculos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:EntradasAMuseosExposicionesEspectaculos</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_ServicioDeTransportePublicoUrbano">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:ServicioDeTransportePublicoUrbano</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_OtrosPreciosPublicos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:OtrosPreciosPublicos</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_ParaLaEjecucionDeObras">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:ParaLaEjecucionDeObras</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_ParaElEstablecimientoOAmpliacionDeServicios">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:ParaElEstablecimientoOAmpliacionDeServicios</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_ReintegroDeAvales">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:ReintegroDeAvales</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_OtrosReintegrosDeOperacionesCorrientes">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:OtrosReintegrosDeOperacionesCorrientes</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_Multas">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:Multas</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_RecargosDelPeriodoEjecutivoYPorDeclaracionExtemporaneaSinRequerimientoPrevio">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:RecargosDelPeriodoEjecutivoYPorDeclaracionExtemporaneaSinRequerimientoPrevio</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_EconomicaIngresos_TasasPreciosPublicosYOtrosIngresos_OtrosIngresos_InteresesDeDemora">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:EconomicaIngresos_TasasPreciosPublicosYOtrosIngresos_OtrosIngresos_InteresesDeDemora</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_PrestacionPersonal">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:PrestacionPersonal</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_PrestacionDeTransporte">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:PrestacionDeTransporte</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_IngresosPorActuacionesDeUrbanizacion">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:IngresosPorActuacionesDeUrbanizacion</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_AprovechamientosUrbanisticos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:AprovechamientosUrbanisticos</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_IndemnizacionesDeSegurosDeNoVida">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:IndemnizacionesDeSegurosDeNoVida</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_OtrosIngresosDiversos">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:OtrosIngresosDiversos</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TransferenciaCorrientes_DeLaAdministracionGeneralDeLaEntidadLocal">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:TransferenciaCorrientes_DeLaAdministracionGeneralDeLaEntidadLocal</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TransferenciaCorrientes_DeOrganismosAutonomosDeLaEntidadLocal">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:TransferenciaCorrientes_DeOrganismosAutonomosDeLaEntidadLocal</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TransferenciaCorrientes_DeLaAdministracionDelEstado">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
#         <xbrldi:explicitMember dimension="trimloc2017-econ-ingr:Cuentasdimension">trimloc2017-econ-ingr-cuentas:TransferenciaCorrientes_DeLaAdministracionDelEstado</xbrldi:explicitMember>
#       </xbrli:segment>
#     </xbrli:entity>
#     <xbrli:period>
#       <xbrli:instant>2021-03-31</xbrli:instant>
#     </xbrli:period>
#   </xbrli:context>
#   <xbrli:context id="IdContextosEconomicaIngresos_TransferenciaCorrientes_DeLaSeguridadSocial">
#     <xbrli:entity>
#       <xbrli:identifier scheme="P4400000H">EXCMA.DIPUTACION PROVINCIAL TERUEL      </xbrli:identifier>
#       <xbrli:segment>
# ...
# <trimloc2017-econ-gast-importes:ObservacionesDesgloseGastos decimals="2" contextRef="IdContextosEconomicaGastos_EconomicaGastos_PasivosFinancieros" unitRef="euro"></trimloc2017-econ-gast-importes:ObservacionesDesgloseGastos>
# <trimloc2017-remt:ImporteEjercicioActual decimals="2" contextRef="R29t" unitRef="euro">40464053.00</trimloc2017-remt:ImporteEjercicioActual>
# <trimloc2017-remt:ImporteEjercicioActual decimals="2" contextRef="R09t" unitRef="euro">25641048.19</trimloc2017-remt:ImporteEjercicioActual>
# <trimloc2017-remt:ImporteEjercicioActual decimals="2" contextRef="R01" unitRef="euro">55361.42</trimloc2017-remt:ImporteEjercicioActual>
# <trimloc2017-remt:ImporteEjercicioActual decimals="2" contextRef="R02" unitRef="euro">261735.84</trimloc2017-remt:ImporteEjercicioActual>
# <trimloc2017-remt:ImporteEjercicioActual decimals="2" contextRef="R04" unitRef="euro">25323950.93</trimloc2017-remt:ImporteEjercicioActual>
# <trimloc2017-remt:ImporteEjercicioActual decimals="2" contextRef="R19t" unitRef="euro">504108.92</trimloc2017-remt:ImporteEjercicioActual>
# <trimloc2017-remt:ImporteEjercicioActual decimals="2" contextRef="R11" unitRef="euro">64575.26</trimloc2017-remt:ImporteEjercicioActual>
# <trimloc2017-remt:ImporteEjercicioActual decimals="2" contextRef="R12" unitRef="euro">85408.30</trimloc2017-remt:ImporteEjercicioActual>
# <trimloc2017-remt:ImporteEjercicioActual decimals="2" contextRef="R15" unitRef="euro">354125.36</trimloc2017-remt:ImporteEjercicioActual>
# <trimloc2017-remt:ImporteEjercicioActual decimals="2" contextRef="Context_Instant_PartidasPendientesDeAplicacion" unitRef="euro">-155416.81</trimloc2017-remt:ImporteEjercicioActual>
# <trimloc2017-remt:ImporteEjercicioActual decimals="2" contextRef="Context_Instant_PartidasPendientesDeAplicacion_CobrosRealizadosPendientesDeAplicacionDefinitiva" unitRef="euro">159508.49</trimloc2017-remt:ImporteEjercicioActual>
# <trimloc2017-remt:ImporteEjercicioActual decimals="2" contextRef="Context_Instant_PartidasPendientesDeAplicacion_PagosRealizadosPendientesDeAplicacionDefinitiva" unitRef="euro">4091.68</trimloc2017-remt:ImporteEjercicioActual>
# <trimloc2017-remt:ImporteEjercicioActual decimals="2" contextRef="R39t" unitRef="euro">65445575.46</trimloc2017-remt:ImporteEjercicioActual>
# <trimloc2017-remt:ImporteEjercicioActual decimals="2" contextRef="R41" unitRef="euro">80125.43</trimloc2017-remt:ImporteEjercicioActual>
# <trimloc2017-remt:ImporteEjercicioActual decimals="2" contextRef="R42" unitRef="euro">1776599.45</trimloc2017-remt:ImporteEjercicioActual>
# <trimloc2017-remt:ImporteEjercicioActual decimals="2" contextRef="R49t" unitRef="euro">63588850.58</trimloc2017-remt:ImporteEjercicioActual>
# <trimloc2017-remt:ImporteEjercicioActual decimals="2" contextRef="R59t" unitRef="euro">210410.12</trimloc2017-remt:ImporteEjercicioActual>
# <trimloc2017-remt:ImporteEjercicioActual decimals="2" contextRef="R69t" unitRef="euro">131.25</trimloc2017-remt:ImporteEjercicioActual>
# <trimloc2017-remt:ImporteEjercicioActual decimals="2" contextRef="R79" unitRef="euro">63378309.21</trimloc2017-remt:ImporteEjercicioActual>
# <trimloc2017-anexo1:ObligacionesReconocidas decimals="2" contextRef="IdContextosAnexo1_InteresesDeDeudaPublica" unitRef="euro">0.00</trimloc2017-anexo1:ObligacionesReconocidas>
# <trimloc2017-anexo1:InteresesDevengados decimals="2" contextRef="IdContextosAnexo1_InteresesDeDeudaPublica" unitRef="euro">0.00</trimloc2017-anexo1:InteresesDevengados>
# <trimloc2017-anexo1:ObligacionesReconocidas decimals="2" contextRef="IdContextosAnexo1_InteresesDePrestamosYOtrasOperacionesFinancieras" unitRef="euro">0.00</trimloc2017-anexo1:ObligacionesReconocidas>
# <trimloc2017-anexo1:InteresesDevengados decimals="2" contextRef="IdContextosAnexo1_InteresesDePrestamosYOtrasOperacionesFinancieras" unitRef="euro">0.00</trimloc2017-anexo1:InteresesDevengados>
# <trimloc2017-anexo1:ObligacionesReconocidas decimals="2" contextRef="IdContextosAnexo1_InteresesDeDepositosYFianzas" unitRef="euro">0.00</trimloc2017-anexo1:ObligacionesReconocidas>
# <trimloc2017-anexo1:InteresesDevengados decimals="2" contextRef="IdContextosAnexo1_InteresesDeDepositosYFianzas" unitRef="euro">0.00</trimloc2017-anexo1:InteresesDevengados>
# <trimloc2017-anexo1:ObligacionesReconocidas decimals="2" contextRef="IdContextosAnexo1_OtrosIntereses352y358" unitRef="euro">0.00</trimloc2017-anexo1:ObligacionesReconocidas>
# <trimloc2017-anexo1:InteresesDevengados decimals="2" contextRef="IdContextosAnexo1_OtrosIntereses352y358" unitRef="euro">0.00</trimloc2017-anexo1:InteresesDevengados>
# <trimloc2017-anexo1:ObligacionesReconocidas decimals="2" contextRef="IdContextosAnexo1_EjecucionDeAvales357" unitRef="euro">0.00</trimloc2017-anexo1:ObligacionesReconocidas>
# <trimloc2017-anexo1:InteresesDevengados decimals="2" contextRef="IdContextosAnexo1_EjecucionDeAvales357" unitRef="euro">0.00</trimloc2017-anexo1:InteresesDevengados>
# <trimloc2017-anexo1:ObligacionesReconocidas decimals="2" contextRef="IdContextosAnexo1_OperacionesDeIntercambioFinanciero" unitRef="euro">0.00</trimloc2017-anexo1:ObligacionesReconocidas>
# <trimloc2017-anexo1:InteresesDevengados decimals="2" contextRef="IdContextosAnexo1_OperacionesDeIntercambioFinanciero" unitRef="euro">0.00</trimloc2017-anexo1:InteresesDevengados>
# <trimloc2017-anexo1:ObligacionesReconocidas decimals="2" contextRef="IdContextosAnexo1_GastosDeFormalizacionEmisionModificacionYCancelacion" unitRef="euro">0.00</trimloc2017-anexo1:ObligacionesReconocidas>
# <trimloc2017-anexo1:InteresesDevengados decimals="2" contextRef="IdContextosAnexo1_GastosDeFormalizacionEmisionModificacionYCancelacion" unitRef="euro">0.00</trimloc2017-anexo1:InteresesDevengados>
# <trimloc2017-anexo1:ObligacionesReconocidas decimals="2" contextRef="IdContextosAnexo1_DiferenciasDeCambio" unitRef="euro">0.00</trimloc2017-anexo1:ObligacionesReconocidas>
# <trimloc2017-anexo1:InteresesDevengados decimals="2" contextRef="IdContextosAnexo1_DiferenciasDeCambio" unitRef="euro">0.00</trimloc2017-anexo1:InteresesDevengados>
# <trimloc2017-anexo1:ObligacionesReconocidas decimals="2" contextRef="IdContextosAnexo1_OtrosGastosFinancieros" unitRef="euro">0.00</trimloc2017-anexo1:ObligacionesReconocidas>
# <trimloc2017-anexo1:InteresesDevengados decimals="2" contextRef="IdContextosAnexo1_OtrosGastosFinancieros" unitRef="euro">0.00</trimloc2017-anexo1:InteresesDevengados>
# <trimloc2017-anexo1:ObligacionesReconocidas decimals="2" contextRef="IdContextosAnexo1_Total" unitRef="euro">0.00</trimloc2017-anexo1:ObligacionesReconocidas>
# <trimloc2017-anexo1:InteresesDevengados decimals="2" contextRef="IdContextosAnexo1_Total" unitRef="euro">0.00</trimloc2017-anexo1:InteresesDevengados>
#   <trimloc2017-anexo5:EntidadesReceptoras contextRef="IdContextosAnexo5_Transferencia1">CORREOS Y TELEGRAFOS, S.A.</trimloc2017-anexo5:EntidadesReceptoras>
#   <trimloc2017-anexo5:NIF contextRef="IdContextosAnexo5_Transferencia1">A83052407</trimloc2017-anexo5:NIF>
#   <trimloc2017-anexo5:Capitulo1 decimals="0" contextRef="IdContextosAnexo5_Transferencia1" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo1>
#   <trimloc2017-anexo5:Capitulo2 decimals="0" contextRef="IdContextosAnexo5_Transferencia1" unitRef="euro">10.79</trimloc2017-anexo5:Capitulo2>
#   <trimloc2017-anexo5:Capitulo4 decimals="0" contextRef="IdContextosAnexo5_Transferencia1" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo4>
#   <trimloc2017-anexo5:Capitulo6 decimals="0" contextRef="IdContextosAnexo5_Transferencia1" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo6>
#   <trimloc2017-anexo5:Capitulo7 decimals="0" contextRef="IdContextosAnexo5_Transferencia1" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo7>
#   <trimloc2017-anexo5:Capitulo8 decimals="0" contextRef="IdContextosAnexo5_Transferencia1" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo8>
#   <trimloc2017-anexo5:EntidadesReceptoras contextRef="IdContextosAnexo5_Transferencia2">PRENSA DE TERUEL S.L.</trimloc2017-anexo5:EntidadesReceptoras>
#   <trimloc2017-anexo5:NIF contextRef="IdContextosAnexo5_Transferencia2">B44249373</trimloc2017-anexo5:NIF>
#   <trimloc2017-anexo5:Capitulo1 decimals="0" contextRef="IdContextosAnexo5_Transferencia2" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo1>
#   <trimloc2017-anexo5:Capitulo2 decimals="0" contextRef="IdContextosAnexo5_Transferencia2" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo2>
#   <trimloc2017-anexo5:Capitulo4 decimals="0" contextRef="IdContextosAnexo5_Transferencia2" unitRef="euro">849129.68</trimloc2017-anexo5:Capitulo4>
#   <trimloc2017-anexo5:Capitulo6 decimals="0" contextRef="IdContextosAnexo5_Transferencia2" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo6>
#   <trimloc2017-anexo5:Capitulo7 decimals="0" contextRef="IdContextosAnexo5_Transferencia2" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo7>
#   <trimloc2017-anexo5:Capitulo8 decimals="0" contextRef="IdContextosAnexo5_Transferencia2" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo8>
#   <trimloc2017-anexo5:EntidadesReceptoras contextRef="IdContextosAnexo5_Transferencia3">AYTO ABEJUELA</trimloc2017-anexo5:EntidadesReceptoras>
#   <trimloc2017-anexo5:NIF contextRef="IdContextosAnexo5_Transferencia3">P4400200D</trimloc2017-anexo5:NIF>
#   <trimloc2017-anexo5:Capitulo1 decimals="0" contextRef="IdContextosAnexo5_Transferencia3" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo1>
#   <trimloc2017-anexo5:Capitulo2 decimals="0" contextRef="IdContextosAnexo5_Transferencia3" unitRef="euro">776.21</trimloc2017-anexo5:Capitulo2>
#   <trimloc2017-anexo5:Capitulo4 decimals="0" contextRef="IdContextosAnexo5_Transferencia3" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo4>
#   <trimloc2017-anexo5:Capitulo6 decimals="0" contextRef="IdContextosAnexo5_Transferencia3" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo6>
#   <trimloc2017-anexo5:Capitulo7 decimals="0" contextRef="IdContextosAnexo5_Transferencia3" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo7>
#   <trimloc2017-anexo5:Capitulo8 decimals="0" contextRef="IdContextosAnexo5_Transferencia3" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo8>
#   <trimloc2017-anexo5:EntidadesReceptoras contextRef="IdContextosAnexo5_Transferencia4">AYTO NOGUERUELAS</trimloc2017-anexo5:EntidadesReceptoras>
#   <trimloc2017-anexo5:NIF contextRef="IdContextosAnexo5_Transferencia4">P4417400A</trimloc2017-anexo5:NIF>
#   <trimloc2017-anexo5:Capitulo1 decimals="0" contextRef="IdContextosAnexo5_Transferencia4" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo1>
#   <trimloc2017-anexo5:Capitulo2 decimals="0" contextRef="IdContextosAnexo5_Transferencia4" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo2>
#   <trimloc2017-anexo5:Capitulo4 decimals="0" contextRef="IdContextosAnexo5_Transferencia4" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo4>
#   <trimloc2017-anexo5:Capitulo6 decimals="0" contextRef="IdContextosAnexo5_Transferencia4" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo6>
#   <trimloc2017-anexo5:Capitulo7 decimals="0" contextRef="IdContextosAnexo5_Transferencia4" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo7>
#   <trimloc2017-anexo5:Capitulo8 decimals="0" contextRef="IdContextosAnexo5_Transferencia4" unitRef="euro">95944.02</trimloc2017-anexo5:Capitulo8>
#   <trimloc2017-anexo5:EntidadesReceptoras contextRef="IdContextosAnexo5_Transferencia5">AYTO TERUEL</trimloc2017-anexo5:EntidadesReceptoras>
#   <trimloc2017-anexo5:NIF contextRef="IdContextosAnexo5_Transferencia5">P4422900C</trimloc2017-anexo5:NIF>
#   <trimloc2017-anexo5:Capitulo1 decimals="0" contextRef="IdContextosAnexo5_Transferencia5" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo1>
#   <trimloc2017-anexo5:Capitulo2 decimals="0" contextRef="IdContextosAnexo5_Transferencia5" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo2>
#   <trimloc2017-anexo5:Capitulo4 decimals="0" contextRef="IdContextosAnexo5_Transferencia5" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo4>
#   <trimloc2017-anexo5:Capitulo6 decimals="0" contextRef="IdContextosAnexo5_Transferencia5" unitRef="euro">113.50</trimloc2017-anexo5:Capitulo6>
#   <trimloc2017-anexo5:Capitulo7 decimals="0" contextRef="IdContextosAnexo5_Transferencia5" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo7>
#   <trimloc2017-anexo5:Capitulo8 decimals="0" contextRef="IdContextosAnexo5_Transferencia5" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo8>
#   <trimloc2017-anexo5:EntidadesReceptoras contextRef="IdContextosAnexo5_Transferencia6">AGENCIA TRIBUTARIA DE TERUEL</trimloc2017-anexo5:EntidadesReceptoras>
#   <trimloc2017-anexo5:NIF contextRef="IdContextosAnexo5_Transferencia6">Q2826000H</trimloc2017-anexo5:NIF>
#   <trimloc2017-anexo5:Capitulo1 decimals="0" contextRef="IdContextosAnexo5_Transferencia6" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo1>
#   <trimloc2017-anexo5:Capitulo2 decimals="0" contextRef="IdContextosAnexo5_Transferencia6" unitRef="euro">96.60</trimloc2017-anexo5:Capitulo2>
#   <trimloc2017-anexo5:Capitulo4 decimals="0" contextRef="IdContextosAnexo5_Transferencia6" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo4>
#   <trimloc2017-anexo5:Capitulo6 decimals="0" contextRef="IdContextosAnexo5_Transferencia6" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo6>
#   <trimloc2017-anexo5:Capitulo7 decimals="0" contextRef="IdContextosAnexo5_Transferencia6" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo7>
#   <trimloc2017-anexo5:Capitulo8 decimals="0" contextRef="IdContextosAnexo5_Transferencia6" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo8>
#   <trimloc2017-anexo5:EntidadesReceptoras contextRef="IdContextosAnexo5_Transferencia7">CONFEDERACION HIDROGRAFICA DEL JUCAR</trimloc2017-anexo5:EntidadesReceptoras>
#   <trimloc2017-anexo5:NIF contextRef="IdContextosAnexo5_Transferencia7">Q4617001E</trimloc2017-anexo5:NIF>
#   <trimloc2017-anexo5:Capitulo1 decimals="0" contextRef="IdContextosAnexo5_Transferencia7" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo1>
#   <trimloc2017-anexo5:Capitulo2 decimals="0" contextRef="IdContextosAnexo5_Transferencia7" unitRef="euro">154.54</trimloc2017-anexo5:Capitulo2>
#   <trimloc2017-anexo5:Capitulo4 decimals="0" contextRef="IdContextosAnexo5_Transferencia7" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo4>
#   <trimloc2017-anexo5:Capitulo6 decimals="0" contextRef="IdContextosAnexo5_Transferencia7" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo6>
#   <trimloc2017-anexo5:Capitulo7 decimals="0" contextRef="IdContextosAnexo5_Transferencia7" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo7>
#   <trimloc2017-anexo5:Capitulo8 decimals="0" contextRef="IdContextosAnexo5_Transferencia7" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo8>
#   <trimloc2017-anexo5:EntidadesReceptoras contextRef="IdContextosAnexo5_Transferencia8">FEDERACION ARAGONESA DE MUNICIPIOS COMARCAS Y PROVINCIAS</trimloc2017-anexo5:EntidadesReceptoras>
#   <trimloc2017-anexo5:NIF contextRef="IdContextosAnexo5_Transferencia8">V50221233</trimloc2017-anexo5:NIF>
#   <trimloc2017-anexo5:Capitulo1 decimals="0" contextRef="IdContextosAnexo5_Transferencia8" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo1>
#   <trimloc2017-anexo5:Capitulo2 decimals="0" contextRef="IdContextosAnexo5_Transferencia8" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo2>
#   <trimloc2017-anexo5:Capitulo4 decimals="0" contextRef="IdContextosAnexo5_Transferencia8" unitRef="euro">26566.85</trimloc2017-anexo5:Capitulo4>
#   <trimloc2017-anexo5:Capitulo6 decimals="0" contextRef="IdContextosAnexo5_Transferencia8" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo6>
#   <trimloc2017-anexo5:Capitulo7 decimals="0" contextRef="IdContextosAnexo5_Transferencia8" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo7>
#   <trimloc2017-anexo5:Capitulo8 decimals="0" contextRef="IdContextosAnexo5_Transferencia8" unitRef="euro">0.00</trimloc2017-anexo5:Capitulo8>
# </xbrli:xbrl>
# ': failed to load external entity "<?xml version="1.0" encoding="UTF-8"?>
# <!-- Generated by GESTION 400 on IBM iSeries -->
# <xbrli:xbrl xmlns:xsi="http

# %%
entidades.head()

# %%
entidades.describe()
